# %%
import tensorflow as tf 
from tensorflow import keras
import numpy as np 
from keras.models import Sequential
from keras import optimizers
from keras.layers import Dense
import math

import matplotlib.pyplot as plt

def Y_L(x):
    return 0.5*(6*x-2)*(6*x-2)*math.sin(12*x-4)+10*(x-0.5)-5
#     if (x<0.5):
#         return (0.5*(6*x-2)*(6*x-2)*math.sin(12*x-4))+(10*(x-0.5))-5
#     else:
#         return 3+(0.5*(6*x-2)*(6*x-2)*math.sin(12*x-4))+(10*(x-0.5))-5

def Y_H(x):
    return (6*x-2)*(6*x-2)*math.sin(12*x-4)
#     if (x<0.5):
#         return 2*Y_L(x)-20*x+20
#     else:
#         return 4+2*Y_L(x)-20*x+20

H_x = []
H_y = []
for i in range(0,100,1):
    H_x.append(i/100)
    H_y.append(Y_H(i/100))

H_training_input = np.array([0,0.4,0.6,1])
output_list = []
for i in range(0,4,1):
    output_list.append(Y_H(H_training_input[i]))

H_training_output = np.asarray(output_list)

# plt.plot(H_x,H_y,H_training_input,H_training_output,'ro')
# plt.show()

# %%
# #### Keras model
# model =  Sequential()
# model.add(Dense(20,activation = 'tanh',input_dim=1 ))
# model.add(Dense(20,activation = 'tanh'))
# model.add(Dense(20,activation = 'tanh'))
# model.add(Dense(20,activation = 'tanh'))
# model.add(Dense(1))

# Optimizer = optimizers.SGD(lr =1e-3)
# from keras import losses
# # loss=losses.mean_absolute_error
# # loss = tf.losses.mean_squared_error(data_y, output)
# # Optimizer  = tf.contrib.opt.ScipyOptimizerInterface('mean_absolute_error',method="L-BFGS-B")
# model.compile(optimizer=Optimizer,loss='mean_absolute_error',metrics=['mae'])

# # training 
# history = model.fit(H_training_input,H_training_output,epochs=500,batch_size=8)
# # model.save("Model_single_large_data1.h5")

# predict = []
# predict.append(0.6)
# print(model.predict(np.asarray(predict)))

# %%
# pytorch model
import torch
import torch.nn.functional as F
# %run models_for_multi.ipynb
# import models_for_multi as mfm

# %%
# N is batch size; D_in is input dimension;
# H is hidden dimension; D_out is output dimension.
N, D_in, H, D_out = 4, 1, 50, 1

H_training_input1 = H_training_input.reshape((4,1))
H_training_input2 = H_training_input1.transpose()

H_training_output1 = H_training_output.reshape((4,1))
H_training_output2 = H_training_output1.transpose()

print(type(H_training_input),'###',H_training_input.shape,H_training_input2.shape)

x1 = torch.from_numpy(H_training_input2).float()
y1 = torch.from_numpy(H_training_output2).float()

x = x1.t()
y = y1.t()
print(type(x),x.shape)
print(y.shape)
# Out:
# <class 'numpy.ndarray'> ### (4,) (1, 4)
# <class 'torch.Tensor'> torch.Size([4, 1])
# torch.Size([4, 1])

# %%
# Construct our model by instantiating the class defined above
# model = DynamicNet(D_in, H, D_out)
model = DNN_HF(D_in, H, D_out)
# Construct our loss function and an Optimizer. Training this strange model with
# vanilla stochastic gradient descent is tough, so we use momentum
criterion = torch.nn.MSELoss(reduction='sum')
# optimizer = torch.optim.SGD(model.parameters(), lr=1e-3, momentum=0.2)
optimizer = torch.optim.LBFGS(model.parameters(), lr=1e-3)

for t in range(500):
    # Forward pass: Compute predicted y by passing x to the model
    
    def closure():  
#         optimizer.zero_grad() 
#         y_pred = model(x)
#         # Compute and print loss
#         loss = criterion(y_pred, y)
#         if(t%10 == 0):
#             print(t, loss.item())
#         # Zero gradients, perform a backward pass, and update the weights.
        
#         loss.backward()
#         return loss
#     optimizer.step(closure)
           
        y_pred = model(x)
        # Compute and print loss
        loss = criterion(y_pred, y)
        if(t%10 == 0):
            print(t, loss.item())
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
# 70 226.13873291015625
# 70 226.13870239257812
# 70 226.138671875
# 70 226.13864135742188
# 70 226.13861083984375
# 70 226.13858032226562
# 70 226.1385498046875
# 70 226.13853454589844
# 70 226.13853454589844
# 80 226.13790893554688
# 80 226.13787841796875
# 80 226.13784790039062
# 80 226.13784790039062
# 90 226.1374969482422
# 90 226.13746643066406
# 90 226.137451171875
# 90 226.137451171875
# 100 226.13722229003906
# 100 226.13719177246094
# 100 226.13719177246094
# 110 226.13699340820312
# 110 226.13699340820312
# 120 226.13673400878906
# 120 226.13673400878906
# 130 226.13661193847656
# 130 226.13661193847656
# 140 226.13653564453125
# 140 226.13653564453125
# 150 226.1363067626953
# 150 226.1363067626953
# 160 226.1362762451172
# 160 226.13624572753906
# 160 226.13624572753906
# 170 226.13621520996094
# 170 226.13621520996094
# 180 226.13607788085938
# 180 226.13607788085938
# 190 226.13604736328125
# 190 226.13604736328125
# 200 226.13604736328125
# 200 226.13604736328125
# 210 226.13604736328125
# 210 226.13604736328125
# 220 226.13604736328125
# 220 226.13604736328125
# 230 226.13604736328125
# 230 226.13604736328125
# 240 226.13604736328125
# 240 226.13604736328125
# 250 226.13604736328125
# 250 226.13604736328125
# 260 226.13604736328125
# 260 226.13604736328125
# 270 226.13604736328125
# 270 226.13604736328125
# 280 226.13604736328125
# 280 226.13604736328125
# 290 226.13604736328125
# 290 226.13604736328125
# 300 226.13604736328125
# 300 226.13604736328125
# 310 226.13604736328125
# 310 226.13604736328125
# 320 226.13604736328125
# 320 226.13604736328125
# 330 226.13604736328125
# 330 226.13604736328125
# 340 226.13604736328125
# 340 226.13604736328125
# 350 226.13604736328125
# 350 226.13604736328125
# 360 226.13604736328125
# 360 226.13604736328125
# 370 226.13604736328125
# 370 226.13604736328125
# 380 226.13604736328125
# 380 226.13604736328125
# 390 226.13604736328125
# 390 226.13604736328125
# 400 226.13604736328125
# 400 226.13604736328125
# 410 226.13604736328125
# 410 226.13604736328125
# 420 226.13604736328125
# 420 226.13604736328125
# 430 226.13604736328125
# 430 226.13604736328125
# 440 226.13604736328125
# 440 226.13604736328125
# 450 226.13604736328125
# 450 226.13604736328125
# 460 226.13604736328125
# 460 226.13604736328125
# 470 226.13604736328125
# 470 226.13604736328125
# 480 226.13604736328125
# 480 226.13604736328125
# 490 226.13604736328125
# 490 226.13604736328125

# %%
temp = np.asarray(H_x)
temp1 = temp.reshape((100,1))
temp2 = temp1.transpose()
print(temp2.shape)
t1 = torch.FloatTensor(temp2)
t = t1.t()
prediction = model(t)

plt.plot(H_x,H_y,H_training_input,H_training_output,'ro',H_x,prediction.tolist())
plt.show()
print(model)
# Out:
# (1, 100)
# DNN_HF(
#   (linear1): Linear(in_features=1, out_features=20, bias=True)
#   (linear2): Linear(in_features=20, out_features=20, bias=True)
#   (linear3): Linear(in_features=20, out_features=20, bias=True)
#   (linear4): Linear(in_features=20, out_features=20, bias=True)
#   (linear5): Linear(in_features=20, out_features=20, bias=True)
#   (linear6): Linear(in_features=20, out_features=1, bias=True)
# )

# %%
# torch.save(model,'saved_models/HF_trial4')

# %%
# model2 = torch.load('saved_models/HF_trial3')
# prediction2 = model2(t)


# plt.plot(H_x,H_y,H_training_input,H_training_output,'ro',H_x,prediction2.tolist())
# plt.show()
